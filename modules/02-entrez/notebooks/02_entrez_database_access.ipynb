# %% [markdown]
# ![Logo](../../../resources/logo_horizontal_xm26.jpeg)

# %% [markdown]
# # **Day 2 - Accessing Biological Databases with `Bio.Entrez`**

# %% [markdown]
# **By: [Angelina de Meiras Ottoni]()**
#
# > In this notebook, we will explore how to access biological databases from NCBI using Biopython's `Bio.Entrez` module.
#
# **Objectives**:
# - Understand the structure and role of NCBI Entrez
# - Perform queries using `esearch()`
# - Retrieve data using `efetch()`
# - Parse GenBank files using `Bio.SeqIO`

# %% [markdown]
# ### **What is Entrez?**
#
# * **Entrez** is a data retrieval system developed by [**NCBI**](https://www.ncbi.nlm.nih.gov/).
# * It allows access to multiple biological databases:
#
#   * **PubMed** – literature database.
#   * **GenBank** – nucleotide sequences.
#   * **GEO** – gene expression data.
#   * Many others.
#
# * **You can use Entrez via:**
#
#   * A **web browser** (manual search).
#   * **Programmatic access** using `Bio.Entrez` (automated via Python scripts).

# %% [markdown]
# ### **What is Bio.Entrez?**
#
# * A **Biopython** module for programmatic access to NCBI Entrez databases.
# * It wraps around the [**Entrez Programming Utilities (E-utilities**)](https://www.ncbi.nlm.nih.gov/home/develop/api/), which are a set of web-based tools provided by NCBI.
# * Each E-utility (e.g., `esearch`, `efetch`, `esummary`) corresponds to a Python function in `Bio.Entrez`.
# * The module builds the correct API URLs and ensures usage complies with NCBI guidelines.

# %% [markdown]
# ### **What Format is the Data?**
#
# * Most Entrez results are returned in **XML format**.
# * Ways to handle XML data:
#
#   * Use **Bio.Entrez’s parser** to convert XML into Python objects.
#   * Use Python’s built-in XML libraries (e.g., `xml.etree`, `minidom`).
#   * Parse XML manually using string operations (not recommended).

# %% [markdown]
# ### **Other Possible Formats**
#
# * Depending on the database and endpoint, **Entrez** can return:
#
#   * **FASTA** (for sequences).
#   * **GenBank format** (for annotated sequences).
#   * **MedLine format** (for literature records).

# %% [markdown]
# ### **`Bio.Entrez` Parsers and XML Handling**
#
# * `Bio.Entrez.read()` and `parse()` are used to load and interpret XML data.
# * XML data should be **read in binary mode** to allow proper encoding detection.
#
#   ```python
#   with open('file.xml', 'rb') as handle:
#       record = Entrez.read(handle)
#   ```

# %% [markdown]
# # **1. Setting Up Entrez**

# %%
# %pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting numpy (from biopython)
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 6.2 MB/s eta 0:00:0000:0100:01
# Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Installing collected packages: numpy, biopython
# Successfully installed biopython-1.87 numpy-2.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Entrez module from Biopython
from Bio import Entrez

# %%
# Always tell NCBI who you are
Entrez.email = 'angelina.ottoni@ufpe.br'

# %% [markdown]
# *Note* 🗒️ [How to get an API Key](https://support.nlm.nih.gov/kbArticle/?pn=KA-05317)

# %%
Entrez.tool = 'biopython_tutorial'

# %% [markdown]
# ### **Entrez Usage Guidelines**
#
# >Before accessing NCBI's online resources using Biopython (e.g., via Bio.Entrez), make sure to read the [NCBI’s Entrez User Requirements](https://www.ncbi.nlm.nih.gov/books/NBK25497/#_chapter2_Usage_Guidelines_and_Requiremen_). Failing to follow these guidelines may result in your IP address being blocked by NCBI.

# %% [markdown]
# **1. Schedule Large Requests Wisely**
#
# * For more than **100 requests**, run them:
#
#   * During **weekends** or
#   * **Outside peak hours in the USA** (e.g., late night or early morning UTC).
# * This is **your responsibility** to manage.
#
# ---
# **3. Respect Rate Limits**
#
# * **With API key**: up to **10 requests/second**
# * **Without API key**: up to **3 requests/second**
# * Biopython handles these limits automatically.
#
# **Setting your API key:**
#
# ```python
# from Bio import Entrez
# Entrez.api_key = "YourAPIKey"
# ```
#
# ---
#
# **4. Always Set an Email Address**
#
# * NCBI **requires** an email address for contact in case of issues.
# * Use the `email` parameter globally or per request.
#
# **Global setting:**
#
# ```python
# from Bio import Entrez
# Entrez.email = "your.email@example.com"
# ```
#
# > ⚠️ Do not use fake emails. If abuse is detected, NCBI will try to contact you before blocking your access.
#
# ---
#
# **5. Identify Your Tool**
#
# * If using Biopython as part of a larger tool or script, specify the `tool` name.
#
# **Global setting:**
#
# ```python
# from Bio import Entrez
# Entrez.tool = "MyScriptOrApp"
# ```
#
# * Default value is `"Biopython"`

# %% [markdown]
# # **2. Searching NCBI Databases with `esearch()`**

# %% [markdown]
# ## 🔍 **Using `Entrez.esearch()`**
#
# - `Entrez.esearch()` is a function from the `Bio.Entrez` module in Biopython.
# - It allows you to **search records** in NCBI databases programmatically.
#
# >This function is equivalent to searching on the NCBI website, but within Python scripts or notebooks.

# %% [markdown]
# ### ⚙️ **Key Parameters of `Entrez.esearch()`**
#
# | Parameter     | Description                                                                 |
# |---------------|-----------------------------------------------------------------------------|
# | `db`*          | Database name (e.g., `'pubmed'`, `'nucleotide'`, `'gene'`)                  |
# | `term`*        | Search term (e.g., `'BRCA1[Gene]'`, `'Homo sapiens[Organism]'`)             |
# | `retmax`      | Maximum number of results to return *(default: 20)*                           |
# | `sort`        | Sorting method (e.g., `'relevance'`, `'date'`)                              |

# %% [markdown]
# ### **Usage Example: `Entrez.esearch()`**

# %%
# Search the NCBI Nucleotide database for records related to the organism Lachnocladium
handle = Entrez.esearch(db='nucleotide', term='"Lachnocladium"[Organism]', idtype='acc', RetMax='30')

# Parse the search results (XML format) into a Python dictionary
record = Entrez.read(handle)

# Close the handle to free resources
handle.close()

print(record['IdList'])
# Out:
# ['PP727853.1', 'OR527383.1', 'OQ211534.1', 'OQ878425.1', 'OP580230.1', 'OP580229.1', 'KEQB00000000.1', 'MZ264407.1', 'MK546809.1', 'MH260055.1', 'MH260054.1', 'MH260053.1', 'MH260052.1', 'MH260051.1', 'MH260037.1', 'MH260036.1', 'MH260035.1', 'MH260034.1', 'MH260033.1', 'KC348469.1', 'AF506461.1', 'DQ192176.1', 'DQ154110.1', 'DQ457625.1']

# %% [markdown]
# **`idtype`**
#
# - Specifies the type of identifier to return for sequence databases (nuccore, popset, protein).
# - *By default, ESearch returns GI numbers in its output.*
# - If idtype is set to ‘acc’, ESearch will return **accession.version** identifiers rather than GI numbers.

# %% [markdown]
# #### 📌 **Variables**
#
# - `handle`: a response object returned by `Entrez.esearch()`. It contains the raw XML data from NCBI.
# - `record`: a parsed Python dictionary created by `Entrez.read(handle)`, which includes:
#   - `'Count'`: the total number of records matching the search term.
#   - `'RetMax'`: the maximum number of records returned in this request (default is 20).
#   - `'IdList'`: a list of unique IDs (UIDs) for the matched records.

# %% [markdown]
# 📝 **Note:**
# - The variable names `handle` and `record` are **just conventional**.
# - You can use any valid variable name (e.g., `response`, `data`, etc.).
# - However, using descriptive names helps keep your code clear and readable.

# %%
type(record)
# Out:
# Bio.Entrez.Parser.DictionaryElement

# %%
record.keys()
# Out:
# dict_keys(['Count', 'RetMax', 'RetStart', 'IdList', 'TranslationSet', 'TranslationStack', 'QueryTranslation'])

# %%
record['TranslationStack']
# Out:
# [{'Term': '"Lachnocladium"[Organism]', 'Field': 'Organism', 'Count': '24', 'Explode': 'Y'}, 'GROUP']

# %% [markdown]
# ### **Exploring the Results**

# %%
# Display total number of matched entries
print('Total results found:', record['Count'])

# Display number of results returned (default is 20)
print('Number of results returned:', record['RetMax'])
# Out:
# Total results found: 24
# Number of results returned: 24

# %% [markdown]
# ### ⚠️ **Why was only 20 returned, but 24 found?**
#
# By default, `Entrez.esearch()` returns a maximum of 20 results unless you specify otherwise using the `retmax` parameter.
#
# - `record['Count']`: tells you how many results matched your search (in our case, 24).
# - `record['RetMax']`: tells you how many results were actually returned (default is 20).
#
# To retrieve more results, increase `retmax` in the function call.

# %% [markdown]
# ### **Getting All Results**

# %%
handle = Entrez.esearch(db='nucleotide', term='"Lachnocladium"[Organism]', retmax=24)
record = Entrez.read(handle)
handle.close()

print('Now returned:', len(record['IdList']), 'IDs')
# Out:
# Now returned: 24 IDs

# %%
record['RetMax']
# Out:
# '24'

# %%
record['Count']
# Out:
# '24'

# %% [markdown]
# ### **How to build the term parameter in `Entrez.esearch()`**

# %% [markdown]
# #### 🧠 **What is `term`?**
# - The `term` parameter defines the *search query*. It tells NCBI what you want to find, in which field, and how to combine multiple conditions.
#
#
# ```python
# Example:
#     term = '"Homo sapiens"[Organism] AND BRCA1[Gene]'
# ```

# %% [markdown]
# #### 📚 **Useful ways to learn how to write `term`**
#
# **1. Use the NCBI Web Interface to Build Queries**
# - **Tip**: Anything you can search on the NCBI site can be replicated via `term`.
#
# **2. Documentation:**
# - [Entrez Help – Search Field Descriptions and Tags](https://www.ncbi.nlm.nih.gov/books/NBK49540/)
# - [E-utilities documentation](https://www.ncbi.nlm.nih.gov/books/NBK25499/)
# - [PubMed Search Tags](https://pubmed.ncbi.nlm.nih.gov/help/#search-tags)

# %% [markdown]
# ### 🔤 **Common field tags**
#
# - `[Organism]`     → Search by organism name
# - `[Gene]`         → Search by gene symbol
# - `[Title]`        → Search terms in the title
# - `[Author]`       → Useful in PubMed
# - `[Accession]`    → Search by accession number
# - `[All Fields]`   → Generic, less precise
#
# **Example:**
#
# ```python
#     '"Lachnocladium"[Organism]'
# ```

# %% [markdown]
# ### ⚙️ **Boolean operators**
#
# - `AND` → both conditions must be true
# - `OR` → either condition is true
# - `NOT` → exclude results
#
# **Examples:**
#
# ```python
# '"Lachnocladium"[Organism] AND ITS[Title]'
# 'BRCA1[Gene] OR TP53[Gene]'
# '"Homo sapiens"[Organism] NOT mitochondrion[Filter]'
# ```

# %% [markdown]
# ### **🧪 Try it out!**
# - Modify the query to search for sequences related to the BRCA1 gene in *Mus musculus*.

# %% [markdown]
# # **3. Fetching Sequence Records with `Entrez.efetch()`**

# %% [markdown]
# ## 🔍 **Using `Entrez.efetch()`**
#
# - The `Entrez.efetch()` function from the `Bio.Entrez` module (Biopython) is used to **fetch full records** from NCBI databases such as **Nucleotide**, **Protein**, **PubMed**, and more.
#
# - It is a key function when you already know the **ID(s)** of the entries you're interested in and want to retrieve **detailed content**, like full sequences or article metadata.
#
# >**Remember:** Always set your email using `Entrez.email` before making requests. NCBI requires it for tracking and contact in case of misuse.

# %% [markdown]
# ### ⚙️ **Key Parameters of `Entrez.efetch()`**
#
# | Parameter    | Description                                                                 |
# |--------------|-----------------------------------------------------------------------------|
# | `db`         | Name of the NCBI database (`'nucleotide'`, `'protein'`, `'pubmed'`, etc.)   |
# | `id`         | A single ID or list of IDs of the records to fetch                          |
# | `rettype`    | Return type (e.g., `'gb'` for GenBank, `'fasta'`, `'medline'`)              |
# | `retmode`    | Return mode (`'text'`, `'xml'`, `'asn.1'`)                                  |
# | `retstart`   | (Optional) Starting position (for partial retrieval of large sets)          |
# | `retmax`     | (Optional) Maximum number of records to retrieve                            |

# %% [markdown]
# ### **Usage Example: `Entrez.efetch()`**

# %%
ids = record['IdList']
handle = Entrez.efetch(db='nucleotide', id=ids, rettype='gb', retmode='text')
gb_data = handle.read()
handle.close()

print(gb_data[:1000])  # Print only the first 1000 characters
# Out:
# LOCUS       PP727853                 525 bp    DNA     linear   PLN 25-APR-2025
# DEFINITION  Lachnocladium schweinfurthianum voucher IAvH-TRI-MR150 internal
#             transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene,
#             complete sequence; and internal transcribed spacer 2, partial
#             sequence.
# ACCESSION   PP727853
# VERSION     PP727853.1
# KEYWORDS    .
# SOURCE      Lachnocladium schweinfurthianum
#   ORGANISM  Lachnocladium schweinfurthianum
#             Eukaryota; Fungi; Dikarya; Basidiomycota; Agaricomycotina;
#             Agaricomycetes; Russulales; Lachnocladiaceae; Lachnocladium.
# REFERENCE   1  (bases 1 to 525)
#   AUTHORS   Rosas,M., Vasco,A. and Gonzalez,M.
#   TITLE     Fungus from Ecoreserve La Tribuna (Huila-Neiva), Biomonitores
#             program
#   JOURNAL   Unpublished
# REFERENCE   2  (bases 1 to 525)
#   AUTHORS   Rosas,M., Vasco,A. and Gonzalez,M.
#   TITLE     Direct Submission
#   JOURNAL   Submitted (25-APR-2024) Biologia, Universidad de Caldas, Vereda

# %% [markdown]
# # **4. Parsing GenBank Files with `Bio.SeqIO`**

# %% [markdown]
# >`Bio.SeqIO` is a Biopython module for **input/output operations** with biological sequences.
#
# - It supports a wide range of **file formats**, such as:
#     - `fasta`
#     - `genbank`
#     - `embl`
#     - `phylip`
#     - and more
#
# - It provides a simple interface to **read, write, parse, and iterate** over sequence records as `SeqRecord` objects.

# %% [markdown]
# #### **Overview of `Bio.SeqIO.parse()`**
#
# The `SeqIO.parse()` function is used to read multiple records from a file. It takes two main arguments:
#
# - `handle`: A file handle (opened in text mode) or a string path to the file.
# - `format`: The format of the file (e.g., `'genbank'`, `'fasta'`, `'embl'`).
#
# It returns an iterator over `SeqRecord` objects, which represent individual biological sequences with associated annotations.

# %%
# Import the SeqIO module for reading sequence files
from Bio import SeqIO  
# Import StringIO to treat a string as a file-like object
from io import StringIO

# %%
# Convert the GenBank data string into a file-like object
gb_handle = StringIO(gb_data)

# %%
# Parse the GenBank-formatted data and iterate over sequence records
for seq_record in SeqIO.parse(gb_handle, 'genbank'):
    print(f'ID: {seq_record.id}')  
    print(f'Description: {seq_record.description}')  
    print(f'Sequence length: {len(seq_record.seq)}')
# Out:
# ID: PP727853.1
# Description: Lachnocladium schweinfurthianum voucher IAvH-TRI-MR150 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 525
# ID: OR527383.1
# Description: Lachnocladium sp. voucher SL1136 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 597
# ID: OQ211534.1
# Description: Lachnocladium sp. voucher RLC74 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# Sequence length: 676
# ID: OQ878425.1
# Description: Lachnocladium sp. 'sp. 01' isolate RLC_647_iNat_122533417 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence
# Sequence length: 763
# ID: OP580230.1
# Description: Lachnocladium sp. voucher ARF-4928 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 656
# ID: OP580229.1
# Description: Lachnocladium sp. voucher ARF-4670 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 543
# ID: KEQB00000000.1
# Description: TLS: root associated fungus metagenome ribosomal RNA internal transcribed spacer region, targeted locus study
# Sequence length: 4396
# ID: MZ264407.1
# Description: Lachnocladium sp. voucher RC-MART-10-038 small subunit ribosomal RNA gene and internal transcribed spacer 1, partial sequence
# Sequence length: 258
# ID: MK546809.1
# Description: Lachnocladium sp. voucher GG-GUY-12-145 small subunit ribosomal RNA gene and internal transcribed spacer 1, partial sequence
# Sequence length: 209
# ID: MH260055.1
# Description: Lachnocladium cf. brasiliense voucher CALD161213_01 large subunit ribosomal RNA gene, partial sequence
# Sequence length: 833
# ID: MH260054.1
# Description: Lachnocladium cf. brasiliense voucher KM57848 clone 3 large subunit ribosomal RNA gene, partial sequence
# Sequence length: 831
# ID: MH260053.1
# Description: Lachnocladium cf. brasiliense voucher KM57848 clone 2 large subunit ribosomal RNA gene, partial sequence
# Sequence length: 793
# ID: MH260052.1
# Description: Lachnocladium cf. brasiliense voucher KM57848 clone 1 large subunit ribosomal RNA gene, partial sequence
# Sequence length: 832
# ID: MH260051.1
# Description: Lachnocladium schweinfurthianum voucher KM49740 clone 1 large subunit ribosomal RNA gene, partial sequence
# Sequence length: 829
# ID: MH260037.1
# Description: Lachnocladium cf. brasiliense voucher CALD161213_01 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 692
# ID: MH260036.1
# Description: Lachnocladium cf. brasiliense voucher KM57848 clone 3 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 697
# ID: MH260035.1
# Description: Lachnocladium cf. brasiliense voucher KM57848 clone 2 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 697
# ID: MH260034.1
# Description: Lachnocladium cf. brasiliense voucher KM57848 clone 1 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 696
# ID: MH260033.1
# Description: Lachnocladium schweinfurthianum voucher KM49740 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 690
# ID: KC348469.1
# Description: Lachnocladium schweinfurthianum voucher URM 84267 internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 640
# ID: AF506461.1
# Description: Lachnocladium sp. KHL10556 5.8S ribosomal RNA gene, partial sequence; internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence
# Sequence length: 1245
# ID: DQ192176.1
# Description: Lachnocladium sp. BK171002-23 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1 and 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# Sequence length: 540
# ID: DQ154110.1
# Description: Lachnocladium sp. BK171002-23 isolate AFTOL-ID 1556 25S ribosomal RNA gene, partial sequence
# Sequence length: 1410
# ID: DQ457625.1
# Description: Lachnocladium sp. BK171002-23 18S small subunit ribosomal RNA gene, partial sequence
# Sequence length: 1792

# %% [markdown]
# # **5. Exploring Other Databases**

# %%
handle = Entrez.esearch(db='protein', term='hemoglobin[Title] AND human[Organism]', idtype='acc')
record = Entrez.read(handle)
handle.close()
print(record['IdList'])
# Out:
# ['9CQW_D', '9CQW_C', '9CQW_B', '9CQW_A', '9CQV_D', '9CQV_C', '9CQV_B', '9CQV_A', '9CQU_D', '9CQU_C', '9CQU_B', '9CQU_A', '9CQT_D', '9CQT_C', '9CQT_B', '9CQT_A', '9CQS_D', '9CQS_C', '9CQS_B', '9CQS_A']

# %%
record['Count']
# Out:
# '2667'

# %% [markdown]
# # **6. Challenge**

# %% [markdown]
# Combine everything you've learned so far:
# - Search for a mitochondrial gene in *Pan troglodytes*
# - Fetch the GenBank record
# - Extract the gene names and sequence lengths

# %% [markdown]
# # **7. Wrap-up**

# %% [markdown]
# **Today, we:**
# - Learned how to use `esearch()` and `efetch()` from Bio.Entrez
# - Fetched GenBank records and parsed them with `Bio.SeqIO`
# - Practiced filtering and extracting biological information
#
# **Next step**: We’ll dive into sequence similarity searches using BLAST!

# %% [markdown]
# [Accessing NCBI’s Entrez databases](https://biopython.org/docs/dev/Tutorial/chapter_entrez.html)
